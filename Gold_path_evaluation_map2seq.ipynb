# %%
import re
import math
import networkx as nx
import matplotlib.pyplot as plt
import pandas as pd
import json
import numpy as np
import logging
from sentence_transformers import SentenceTransformer, util

# %%
# Setup logging
logging.basicConfig(level=logging.INFO)

# %%
def gold_path(instance, json_file):
    # Load the JSON file
    with open(json_file, 'r') as file:
        try:
            data = json.load(file)
            routes = data if isinstance(data, list) else [data]
        except json.JSONDecodeError as e:
            print(f"Error decoding JSON file: {e}")

    # Convert the list of dictionaries to a DataFrame
    df = pd.DataFrame(routes)

    # Specify the instance ID you want to look for
    target_instance_id = str(instance)  # Replace with the actual instance ID
    data = []
    data.insert(0, "Starting Point")
    # Explore every instance in the 'instances' column
    for index, row in df.iterrows():
        instances = row['instances']  # Get the instances dictionary

        if isinstance(instances, dict):
            if target_instance_id in instances:
                instance_data = instances[target_instance_id]

                # Access the gold navigation lines
                gold_navigation_lines = instance_data.get('gold_navigation_lines', [])

                # Ensure gold_navigation_lines is a list
                if isinstance(gold_navigation_lines, list):
                    # Initialize a list to store output lines
                    output_lines = []

                    # Loop through the navigation lines
                    for i, line in enumerate(gold_navigation_lines):
                        # Skip lines containing "stop"
                        if "stop" in line.strip().lower():
                            line=""
                            break

                        # Replace lines containing 'intersection' with 'Intersection'
                        if 'intersection' in line.lower():
                            line = 'Intersection'

                        # Print the first line
                        if i == 0:
                            output_lines.append(line)  # Print the first line

                        # Check if the line does not start with '- n.' where n is a number
                        if not re.match(r'^\s*\d+\.', line):
                            output_lines.append(line)  # Add the line without the match

                            # Check if there's a next line and add it
                            if i + 1 < len(gold_navigation_lines):
                                output_lines.append(gold_navigation_lines[i + 1])  # Add the next line

                    # Print the selected lines
                    for line in output_lines:
                        data.append(line)  # Collect output lines in data

                else:
                    print(f"Instance ID {target_instance_id} does not contain valid navigation lines.")
                break  # Exit after finding the target instance
        else:
            print(f"Row {index} does not contain a valid instances dictionary.")
    #data.insert(-1, "Target")

    # Initialize lists to hold places and actions
    places = []
    actions = []

    # Iterate through the data and classify each entry
    for entry in data:
        if re.match(r'^\d+\.\s*(forward|right|left|stop)', entry):  # Match actions
            actions.append(entry.split('. ')[1])  # Add only the action (no number)
        else:
            # Replace unwanted phrases and clean the entry
            cleaned_entry = re.sub(r' slightly right\.| ahead\.| slightly left\.| on your left\.| on your right\.', '', entry)
            # Check if the cleaned entry has at most 2 words
            if len(cleaned_entry.split()) <= 4:
                places.append(cleaned_entry)  # Add cleaned entry to places

    # Remove duplicates while retaining the first occurrence and ensuring "Intersection" is included
    unique_places = []
    unique_actions = []

    for i in range(len(places)):
        place = places[i]
        action = actions[i] if i < len(actions) else None

        # Check if the place is "Intersection" or not already in unique_places
        if place == "Intersection":
            unique_places.append(place)

        elif place not in unique_places:  # Corrected condition
            unique_places.append(place)

    # Output the separated lists
    return unique_places

    # Example usage
json_file_path = "/content/dev_results.json"  # Replace with your file path
instance_id_to_search = "6918"
node_gold =  gold_path(instance_id_to_search, json_file_path)

# Print the combined lines
for line in node_gold:
    print(line)
# Out:
# Starting Point
# Project Cozy
# Intersection
# Intersection
# Intersection
# Intersection
# Intersection

# %%
import json
import pandas as pd

def predicted_path(predict_instance, predicted_file):

    # Load the JSON file
    with open(predicted_file, 'r') as file:
        try:
            data = json.load(file)
        except json.JSONDecodeError as e:
            print(f"Error decoding JSON file: {e}")
            return [], []

    # Convert JSON data to DataFrame
    df = pd.DataFrame(data)

    # Search for the matching instance ID
    matching_row = df[df["Instance_id"] == int(predict_instance)]

    if matching_row.empty:
        print(f"No matching instance found for ID: {predict_instance}")
        return [], []

    # Extract the graph data
    graph_list = matching_row.iloc[0]["Graph"]

    # Initialize lists for nodes and actions
    nodes = []
    my_actions = []

    if isinstance(graph_list, dict):
        nodes = [node.title() for node in graph_list.get('Nodes', {}).values()]
        edges = graph_list.get('Edges', [])
        my_actions = [edge.get('action', '').lower() for edge in edges]

    # Define valid actions in lowercase
    valid_actions = ["forward", "left", "right", "stop"]

    # Replace invalid actions with "forward"
    my_actions = [action if action in valid_actions else "forward" for action in my_actions]

    # Clean the nodes
    cleaned_nodes = [
        "Intersection" if any(key.lower() in node.lower() for key in ["intersection", "light", "4-way stop", "t-intersection", "lights", "junction"])
        #else "Target" if any(key.lower() in node.lower() for key in ["target", "(target)"])
        else node.title()
        for node in nodes
    ]
    new_nodes = []
    for my_node in cleaned_nodes:
        if "Target" in my_node:  # Check if "Target" is in the node
            my_node = my_node.replace("Target", "").replace("()", "").strip()  # Remove "(Target)" and clean spaces
            # Add the modified node only if it's not empty
            if my_node != "":
                new_nodes.append(my_node)  # Add the modified node
        else:
            new_nodes.append(my_node)  # Add the node as is

    # Remove the last node if it exists
    #if new_nodes:
     #   new_nodes.pop()
    cleaned_nodes = new_nodes


    return cleaned_nodes

# Path to your JSON file
json_file_predict = "/content/cleaned_cognitive_map_cost.json"

# Specify the instance ID to search for
instance_id_to_search = "6918"

# Get predicted nodes and actions
node_predict = predicted_path(instance_id_to_search, json_file_predict)

# Print the cleaned nodes and actions
print("\nNodes:")
for line_node in node_predict:
    print(line_node)
# Out:
# Nodes:
# Starting Point, Parking
# Project Cozy
# Intersection
# Intersection
# Intersection
# Intersection
# Intersection
# Bagel Shop
# Intersection

# %%
# Path to your JSON file
json_file_predict = '/content/cleaned_cognitive_map_cost.json'
# Path to your JSON file
json_file_GT = '/content/dev_results.json'

# Load the JSON file
with open(json_file_predict, 'r') as file:
    try:
        # Load the entire JSON content
        data = json.load(file)
        # Ensure the data is a list of dictionaries
        routes = data if isinstance(data, list) else [data]
    except json.JSONDecodeError as e:
        print(f"Error decoding JSON file: {e}")
        routes = []

# Convert the list of dictionaries to a DataFrame
df = pd.DataFrame(routes)

# Initialize dictionaries
all_predicted_nodes = {}
all_gold_nodes = {}

# Loop over each graph instance
for i in range(0, 200):
    instance_id = df.loc[i, 'Instance_id']

    # Get Ground Truth nodes
    node_GT = gold_path(instance_id, json_file_GT)

    # Get predicted nodes
    node_predict = predicted_path(instance_id, json_file_predict)

    # Store results in dictionaries
    all_predicted_nodes[instance_id] = node_predict
    all_gold_nodes[instance_id] = node_GT

# %%
# Print or process results
print("Predicted Nodes:", all_predicted_nodes)
print("Gold Nodes:", all_gold_nodes)
# Out:
# Predicted Nodes: {np.int64(6918): ['Starting Point, Parking', 'Project Cozy', 'Intersection', 'Intersection', 'Intersection', 'Intersection', 'Intersection', 'Bagel Shop', 'Intersection'], np.int64(990): ['Starting Point, Bike Rental', 'Intersection', 'Intersection', 'Intersection', 'Intersection', "Dunkin' Donuts", 'Intersection'], np.int64(1017): ['Intersection', 'Intersection', 'Intersection', 'Intersection', 'Intersection', 'Lin Zexu', 'Bike Rental', 'Chatham Green Professional Suites', 'Intersection', 'St. James Church,'], np.int64(5947): ['Intersection', 'Overpass,', 'Intersection', 'Intersection', 'Bike Rental', 'Key Food'], np.int64(6503): ['Starting Point, Outdoor Dining', 'Intersection', 'Vbar Seaport', 'Intersection', 'Abercrombie', 'Intersection', 'Intersection', 'Intersection', 'Intersection', "Mcdonald'S", 'Florist', 'Intersection'], np.int64(1681): ['Intersection', 'Paulaner Restaurant', 'Intersection', 'Bt Kitchen Supplies Inc.', 'Loreley Beer Garden,  For Lease Sign, Taqueria Les'], np.int64(5327): ['Intersection', 'Intersection', 'Intersection', 'Intersection', 'Intersection', 'Intersection', 'Irving Farm', 'Dudleys', 'An Choi,  Bike Rental'], np.int64(6960): ['Starting Point, Bike Rental', 'Intersection', 'Apple Store', 'Intersection', 'Longchamp', 'Intersection', 'Google Store', 'Intersection', 'Chase Bank,'], np.int64(2663): ['Starting Point, Bus Stop', 'Intersection', 'Intersection', 'Right Side Street', 'Intersection', 'Fast Park Garage,'], np.int64(6696): ['Intersection', 'Duane Reade', 'Intersection', 'Intersection', 'Intersection', 'Parking Lot', 'Intersection'], np.int64(993): ['Starting Point', 'Intersection', 'Intersection', 'Intersection', 'Nypd,'], np.int64(1994): ['Intersection', 'Intersection', 'Td Bank', 'Intersection', 'Intersection', 'Intersection', 'Intersection', 'Intersection'], np.int64(4552): ['Intersection', 'Intersection', 'Park', 'Intersection', 'Intersection', 'Intersection', 'Intersection', 'Fire Station', 'Intersection'], np.int64(2840): ['Intersection', 'Intersection', 'Intersection', 'Intersection', 'Playground', 'Intersection', 'Intersection'], np.int64(96): ['Intersection', 'Intersection', 'Park Playground', 'Intersection', 'Intersection', 'Intersection'], np.int64(1966): ['Intersection', 'Intersection', 'Intersection', 'Intersection', 'Rsvp Restaurant Parking Lot'], np.int64(6825): ['Intersection', 'Park', 'Intersection', 'Intersection', 'Td Bank', 'Intersection', 'Intersection', 'Intersection'], np.int64(5180): ['Starting Point, Events That Partial', 'Park', 'Intersection', 'Between Two Parks', 'Intersection', 'Park', 'Intersection', 'Intersection', 'Intersection', 'Farmhouse, , For Garibaldi'], np.int64(5807): ['Intersection', 'Major Road', "People'S Choice Pharmacy", 'Intersection', 'Laundromat', 'A-1 Pizza', 'Intersection', 'Fork', 'Intersection', 'Building Bank,'], np.int64(2879): ['Intersection', 'Chase Bank', 'Intersection', 'Buddhist Temple', 'Intersection', 'Intersection', ", Stop Sign, Wu'S Wonton King"], np.int64(3513): ['Intersection', 'Intersection', 'Park', 'Intersection', 'Intersection', 'Bike Rental,'], np.int64(4806): ['Intersection', 'Intersection', 'School', 'Intersection', 'Intersection', 'Golden Unicorn', 'Chatham Library Yung Sun Seafood Restaurant', 'Intersection'], np.int64(4693): ['Starting Point, Grand Hotel Sign', "Dunkin' Donuts", 'Intersection', 'Tribeca Bagels', 'Intersection', 'Intersection', 'La Colombe', 'Intersection'], np.int64(2523): ['Starting Point, Stores, - Moca- Store Mei-Dick Barbers', 'Intersection', 'Hsbc', 'Intersection', 'Intersection', 'Intersection', 'East West Bank', 'Intersection', 'Chase Bank', 'Intersection'], np.int64(5087): ['Starting Point, Poli Pizza, Zoomo', 'Bus Stop', 'Intersection', 'Bike Rental', 'Intersection', 'Fire Station', 'Intersection', 'Intersection', 'Intersection', 'Intersection'], np.int64(5856): ['Starting Point', 'Roxy Hotel', 'Intersection', 'Post Office', 'Intersection', 'Intersection', 'Intersection' ...
# Gold Nodes: {np.int64(6918): ['Starting Point', 'Project Cozy', 'Intersection', 'Intersection', 'Intersection', 'Intersection', 'Intersection'], np.int64(990): ['Starting Point', 'Intersection', 'Intersection', 'Intersection', "Dunkin' Donuts", 'Intersection'], np.int64(1017): ['Starting Point', 'Lin Zexu', 'Intersection', 'Intersection', 'Intersection', 'Intersection', 'Intersection', 'Intersection', 'A bicycle rental', 'Intersection', 'St. James Church'], np.int64(5947): ['Starting Point', 'Intersection', 'An overpass', 'Intersection', 'Intersection', 'Intersection', 'Key Food'], np.int64(6503): ['Starting Point', 'Vbar Seaport', 'Intersection', 'Intersection', 'Vbar Seaport Abercrombie', 'Intersection', 'Intersection', 'Intersection', "McDonald's", 'Intersection'], np.int64(1681): ['Starting Point', 'Paulaner restaurant', 'Intersection', 'Intersection', 'Intersection', 'Loreley Beer Garden', 'Intersection'], np.int64(5327): ['Starting Point', 'Intersection', 'Intersection', 'Intersection', 'Intersection', 'Intersection', 'Dudleys', 'An Choi restaurant'], np.int64(6960): ['Starting Point', 'Apple Store', 'Intersection', 'Intersection', 'Intersection', 'Chase Bank', 'Google store'], np.int64(2663): ['Starting Point', 'Intersection', 'Intersection', 'Intersection'], np.int64(6696): ['Starting Point', 'Intersection', 'Intersection', 'Intersection', 'Intersection'], np.int64(993): ['Starting Point', 'Intersection', 'Parking lot', 'Intersection', 'Intersection', 'Intersection'], np.int64(1994): ['Starting Point', 'TD Bank', 'Intersection', 'Intersection', 'Intersection', 'Intersection', 'Intersection'], np.int64(4552): ['Starting Point', 'Intersection', 'Intersection', 'Intersection', 'Intersection', 'Intersection', 'Intersection', 'A fire station'], np.int64(2840): ['Starting Point', 'Intersection', 'Intersection', 'Intersection', 'Playground', 'Intersection', 'Intersection', 'Intersection', 'Intersection', 'Wa Lung Kitchen'], np.int64(96): ['Starting Point', 'A park', 'A playground', 'Intersection', 'Intersection', 'Intersection', 'Cleaners'], np.int64(1966): ['Starting Point', 'Intersection', 'Intersection', 'Intersection'], np.int64(6825): ['Starting Point', 'Intersection', 'Intersection', 'Intersection', 'TD Bank', 'Intersection', 'Intersection', 'Mooshoes'], np.int64(5180): ['Starting Point', 'Intersection', 'Intersection', 'Intersection', 'Intersection', 'Intersection'], np.int64(5807): ['Starting Point', 'Intersection', 'Intersection', "People's Choice Pharmacy", 'Intersection', 'Intersection', 'A laundromat', 'A-1 Pizza', 'Intersection', 'Intersection'], np.int64(2879): ['Starting Point', 'Chase', 'Intersection', 'Intersection', 'Buddhist Temple', 'Intersection'], np.int64(3513): ['Starting Point', 'Intersection', 'Intersection', 'A park', 'Intersection', 'Intersection', 'A bike rental'], np.int64(4806): ['Starting Point', 'Intersection', 'Yung Sun Seafood Restaurant', 'Intersection', 'Intersection'], np.int64(4693): ['Starting Point', "Dunkin' Donuts", 'Intersection', 'Tribeca Bagels', 'Intersection', 'Intersection', 'La Colombe', 'Intersection'], np.int64(2523): ['Starting Point', 'Intersection', 'Intersection', 'East West Bank', 'HSBC East West Bank', 'Intersection', 'HSBC', 'Chase', 'Intersection', 'Intersection', 'Intersection'], np.int64(5087): ['Starting Point', 'Intersection', 'Intersection', 'Intersection', 'Intersection', 'Intersection', 'Intersection'], np.int64(5856): ['Starting Point', 'Intersection', 'A post office', 'Intersection', 'Intersection', 'Intersection', 'Intersection'], np.int64(6700): ['Starting Point', 'Intersection', 'Intersection', 'Intersection', 'Intersection', 'Intersection', 'Simply Bakery'], np.int64(2946): ['Starting Point', 'Intersection', 'Intersection', 'Intersection', 'Intersection', 'Liquors', 'Intersection', 'Intersection'], np.int64(1921): ['Starting Point', 'Intersection', 'Intersection', 'Intersection', 'The Butcher Daughter', 'Intersection', 'Esther and Carol'], np.int64(1939) ...

# %% [markdown]
# Task Completion Rate (TC)

# %%
def compute_task_completion_rate(predicted_paths, gold_paths):
    """
    Computes the Task Completion Rate (TC) for each instance and prints results.

    Parameters:
    - predicted_paths (dict): Dictionary {instance_id: [list of predicted nodes]}.
    - gold_paths (dict): Dictionary {instance_id: [list of ground truth nodes]}.

    Returns:
    - float: Average Task Completion Rate (TC) as a percentage.
    """
    successful_tasks = 0
    total_tasks = len(gold_paths)

    if total_tasks == 0:
        return 0.0  # Avoid division by zero

    print("\nTask Completion Rate per Sample:")
    print("-" * 50)

    for instance_id, gold_path in gold_paths.items():
        predicted_path = predicted_paths.get(instance_id, [])

        if not predicted_path or not gold_path:
            print(f"Instance {instance_id}: No valid paths found.")
            continue  # Skip if either path is missing

        # Get the predicted final node and second-to-last predicted node (if available)
        predicted_final_node = predicted_path[-1]

        target_node = gold_path[-1]

        # Allow success if the final predicted node or second-to-last node is the target or its immediate neighbor
        neighboring_nodes = set(gold_path[-2:]) if len(gold_path) > 1 else {target_node}

        success = predicted_final_node == target_node or predicted_final_node in neighboring_nodes

        if success:
            successful_tasks += 1

        print(f"Instance {instance_id}: {'1 Success' if success else '0 Failure'}")

    avg_tc = successful_tasks / total_tasks  # 0.0 - 1.0
    print("\n" + "=" * 50)
    print(f"Overall Task Completion Rate (TC): {avg_tc:.2%}")

    return avg_tc * 100

# Example Usage
predicted_paths = all_predicted_nodes
gold_paths = all_gold_nodes

tc = compute_task_completion_rate(predicted_paths, gold_paths)
# Out:
# Task Completion Rate per Sample:
# --------------------------------------------------
# Instance 6918: 1 Success
# Instance 990: 1 Success
# Instance 1017: 0 Failure
# Instance 5947: 1 Success
# Instance 6503: 1 Success
# Instance 1681: 0 Failure
# Instance 5327: 0 Failure
# Instance 6960: 0 Failure
# Instance 2663: 0 Failure
# Instance 6696: 1 Success
# Instance 993: 0 Failure
# Instance 1994: 1 Success
# Instance 4552: 1 Success
# Instance 2840: 1 Success
# Instance 96: 1 Success
# Instance 1966: 0 Failure
# Instance 6825: 1 Success
# Instance 5180: 0 Failure
# Instance 5807: 0 Failure
# Instance 2879: 0 Failure
# Instance 3513: 0 Failure
# Instance 4806: 1 Success
# Instance 4693: 1 Success
# Instance 2523: 1 Success
# Instance 5087: 1 Success
# Instance 5856: 1 Success
# Instance 6700: 0 Failure
# Instance 2946: 1 Success
# Instance 1921: 1 Success
# Instance 1939: 1 Success
# Instance 3997: 1 Success
# Instance 5523: 1 Success
# Instance 5197: 1 Success
# Instance 1570: 1 Success
# Instance 2045: 1 Success
# Instance 3062: 0 Failure
# Instance 1047: 0 Failure
# Instance 5783: 0 Failure
# Instance 3279: 0 Failure
# Instance 2322: 1 Success
# Instance 6211: 1 Success
# Instance 6633: 1 Success
# Instance 4162: 1 Success
# Instance 344: 1 Success
# Instance 228: 0 Failure
# Instance 6679: 1 Success
# Instance 3608: 1 Success
# Instance 5644: 1 Success
# Instance 5265: 0 Failure
# Instance 2798: 1 Success
# Instance 1780: 1 Success
# Instance 6626: 1 Success
# Instance 2172: 0 Failure
# Instance 5573: 1 Success
# Instance 3319: 0 Failure
# Instance 4320: 1 Success
# Instance 7358: 0 Failure
# Instance 6931: 1 Success
# Instance 2680: 0 Failure
# Instance 2484: 1 Success
# Instance 5940: 1 Success
# Instance 2832: 1 Success
# Instance 1433: 0 Failure
# Instance 5638: 1 Success
# Instance 4868: 1 Success
# Instance 2403: 0 Failure
# Instance 571: 1 Success
# Instance 164: 1 Success
# Instance 5894: 0 Failure
# Instance 4238: 1 Success
# Instance 4548: 1 Success
# Instance 4260: 0 Failure
# Instance 5731: 0 Failure
# Instance 5147: 1 Success
# Instance 7291: 0 Failure
# Instance 4377: 0 Failure
# Instance 1708: 1 Success
# Instance 1259: 1 Success
# Instance 2291: 1 Success
# Instance 5479: 1 Success
# Instance 6338: 1 Success
# Instance 5218: 0 Failure
# Instance 7110: 1 Success
# Instance 2624: 1 Success
# Instance 6329: 1 Success
# Instance 5467: 1 Success
# Instance 5568: 1 Success
# Instance 7369: 1 Success
# Instance 1709: 1 Success
# Instance 3184: 1 Success
# Instance 6032: 1 Success
# Instance 5717: 0 Failure
# Instance 286: 1 Success
# Instance 3189: 0 Failure
# Instance 1160: 1 Success
# Instance 6194: 0 Failure
# Instance 4883: 1 Success
# Instance 939: 0 Failure
# Instance 4300: 1 Success
# Instance 3871: 0 Failure
# Instance 6244: 1 Success
# Instance 3158: 1 Success
# Instance 2138: 0 Failure
# Instance 1232: 1 Success
# Instance 7254: 0 Failure
# Instance 1903: 0 Failure
# Instance 2217: 0 Failure
# Instance 3245: 0 Failure
# Instance 6912: 0 Failure
# Instance 5487: 1 Success
# Instance 3173: 1 Success
# Instance 2509: 1 Success
# Instance 632: 0 Failure
# Instance 7269: 1 Success
# Instance 5297: 0 Failure
# Instance 1591: 1 Success
# Instance 561: 1 Success
# Instance 5395: 0 Failure
# Instance 2349: 1 Success
# Instance 516: 1 Success
# Instance 1700: 1 Success
# Instance 2810: 1 Success
# Instance 2264: 1 Success
# Instance 6087: 1 Success
# Instance 2078: 1 Success
# Instance 6153: 1 Success
# Instance 275: 1 Success
# Instance 4206: 0 Failure
# Instance 597: 1 Success
# Instance 5653: 0 Failure
# Instance 3660: 1 Success
# Instance 3177: 1 Success
# Instance 689: 1 Success
# Instance 5912: 1 Success
# Instance 4402: 1 Success
# Instance 4859: 0 Failure
# Instance 7078: 1 Success
# Instance 7234: 1 Success
# Instance 6889: 1 Success
# Instance 7041: 1 Success
# Instance 6311: 0 Failure
# Instance 6335: 1 Success
# Instance 1539: 1 Success
# Instance 7061: 0 Failure
# Instance 578: 0 Failure
# Instance 5439: 1 Success
# Instance 4642: 0 Failure
# Instance 864: 1 Success
# Instance 4816: 0 Failure
# Instance 2806: 1 Success
# Instance 3083: 1 Success
# Instance 3590: 1 Success
# Instance 1959: 0 Failure
# Instance 1300: 1 Success
# Instance 5428: 1 Success
# Instance 7349: 1 Success
# Instance 4365: 0 Failure
# Instance 5477: 1 Success
# Instance 7595: 0 Failure
# Instance 3638: 1 Success
# Instance 732: 1 Success
# Instance 2795: 1 Success
# Instance 7365: 0 Failure
# Instance 3496: 1 Success
# Instance 4479: 1 Success
# Instance 617: 0 Failure
# Instance 1702: 1 Success
# Instance 5846: 1 Success
# Instance 4946: 0 Failure
# Instance 3557: 1 Success
# Instance 4201: 0 Failure
# Instance 5090: 1 Success
# Instance 5934: 1 Success
# Instance 6383: 1 Success
# Instance 6805: 0 Failure
# Instance 2361: 0 Failure
# Instance 4002: 1 Success
# Instance 7371: 1 Success
# Instance 4989: 1 Success
# Instance 2343: 0 Failure
# Instance 6111: 1 Success
# Instance 851: 0 Failure
# Instance 1928: 0 Failure
# Instance 7619: 1 Success
# Instance 3420: 1 Success
# Instance 5448: 1 Success
# Instance 6094: 1 Success
# Instance 435: 0 Failure
# Instance 7361: 1 Success
# Instance 5868: 0 Failure
# Instance 5853: 1 Success
# Instance 309: 0 Failure
# Instance 6598: 1 Success
# Instance 3835: 1 Success
# Instance 607: 1 Success
# Instance 2257: 1 Success
# Instance 3666: 1 Success
# Instance 6682: 1 Success
# Instance 7494: 1 Success
# Instance 3336: 1 Success
#
# ==================================================
# Overall Task Completion Rate (TC): 66.50%

# %% [markdown]
# Point Accuracy (KPA)

# %%
# Load a pre-trained SBERT model
model = SentenceTransformer("all-MiniLM-L6-v2")

def compute_kpa_semantic(predicted_keypoints, ground_truth_keypoints, similarity_threshold=0.7):
    """
    Computes Key Point Accuracy (KPA) using semantic similarity.
    :param predicted_keypoints: List of predicted keypoints (nodes).
    :param ground_truth_keypoints: List of ground truth keypoints (nodes).
    :param similarity_threshold: Cosine similarity threshold for a match.
    :return: KPA score (float).
    """
    if not predicted_keypoints or not ground_truth_keypoints:
        return 0.0  # Avoid division by zero

    correct_matches = 0

    # Encode keypoints into embeddings
    pred_embeddings = model.encode(predicted_keypoints, convert_to_tensor=True)
    gt_embeddings = model.encode(ground_truth_keypoints, convert_to_tensor=True)

    # Compute cosine similarity matrix
    similarity_matrix = util.pytorch_cos_sim(pred_embeddings, gt_embeddings)

    # Check for matches using the threshold
    for i in range(len(predicted_keypoints)):
        max_sim = similarity_matrix[i].max().item()
        if max_sim >= similarity_threshold:
            correct_matches += 1

    # Compute KPA
    return correct_matches / len(ground_truth_keypoints)

# Example Data
# Compute KPA for each instance
kpa_results = {}
prom_kpa = 0

for instance_id in all_predicted_nodes.keys():
    kpa = compute_kpa_semantic(all_predicted_nodes[instance_id], all_gold_nodes[instance_id])
    kpa_results[instance_id] = kpa
    prom_kpa += kpa
    print(f"Instance {instance_id}: KPA = {kpa:.2f}")

# Compute Average KPA
total_kpa = prom_kpa / len(kpa_results)
print(f"Average KPA = {total_kpa:.2f}")
# Out:
# Instance 6918: KPA = 1.00
# Instance 990: KPA = 1.00
# Instance 1017: KPA = 0.82
# Instance 5947: KPA = 0.71
# Instance 6503: KPA = 0.90
# Instance 1681: KPA = 0.43
# Instance 5327: KPA = 0.88
# Instance 6960: KPA = 1.00
# Instance 2663: KPA = 0.75
# Instance 6696: KPA = 1.00
# Instance 993: KPA = 0.67
# Instance 1994: KPA = 1.14
# Instance 4552: KPA = 1.00
# Instance 2840: KPA = 0.70
# Instance 96: KPA = 0.86
# Instance 1966: KPA = 1.00
# Instance 6825: KPA = 0.88
# Instance 5180: KPA = 0.83
# Instance 5807: KPA = 0.70
# Instance 2879: KPA = 1.00
# Instance 3513: KPA = 0.86
# Instance 4806: KPA = 1.20
# Instance 4693: KPA = 0.88
# Instance 2523: KPA = 0.82
# Instance 5087: KPA = 0.86
# Instance 5856: KPA = 1.14
# Instance 6700: KPA = 0.71
# Instance 2946: KPA = 1.00
# Instance 1921: KPA = 1.00
# Instance 1939: KPA = 1.12
# Instance 3997: KPA = 1.14
# Instance 5523: KPA = 1.00
# Instance 5197: KPA = 1.00
# Instance 1570: KPA = 1.00
# Instance 2045: KPA = 1.00
# Instance 3062: KPA = 0.78
# Instance 1047: KPA = 0.83
# Instance 5783: KPA = 1.00
# Instance 3279: KPA = 0.67
# Instance 2322: KPA = 1.17
# Instance 6211: KPA = 0.86
# Instance 6633: KPA = 0.86
# Instance 4162: KPA = 1.00
# Instance 344: KPA = 0.80
# Instance 228: KPA = 1.00
# Instance 6679: KPA = 2.67
# Instance 3608: KPA = 1.20
# Instance 5644: KPA = 1.00
# Instance 5265: KPA = 1.00
# Instance 2798: KPA = 1.00
# Instance 1780: KPA = 0.80
# Instance 6626: KPA = 1.00
# Instance 2172: KPA = 0.89
# Instance 5573: KPA = 1.17
# Instance 3319: KPA = 1.00
# Instance 4320: KPA = 0.71
# Instance 7358: KPA = 0.88
# Instance 6931: KPA = 0.80
# Instance 2680: KPA = 0.75
# Instance 2484: KPA = 0.83
# Instance 5940: KPA = 1.17
# Instance 2832: KPA = 0.78
# Instance 1433: KPA = 0.86
# Instance 5638: KPA = 1.43
# Instance 4868: KPA = 0.50
# Instance 2403: KPA = 0.75
# Instance 571: KPA = 1.14
# Instance 164: KPA = 0.86
# Instance 5894: KPA = 0.67
# Instance 4238: KPA = 1.12
# Instance 4548: KPA = 1.12
# Instance 4260: KPA = 1.00
# Instance 5731: KPA = 0.83
# Instance 5147: KPA = 1.00
# Instance 7291: KPA = 0.80
# Instance 4377: KPA = 0.75
# Instance 1708: KPA = 0.86
# Instance 1259: KPA = 1.33
# Instance 2291: KPA = 0.83
# Instance 5479: KPA = 0.83
# Instance 6338: KPA = 1.20
# Instance 5218: KPA = 0.29
# Instance 7110: KPA = 1.00
# Instance 2624: KPA = 1.00
# Instance 6329: KPA = 0.71
# Instance 5467: KPA = 0.56
# Instance 5568: KPA = 0.88
# Instance 7369: KPA = 0.80
# Instance 1709: KPA = 0.78
# Instance 3184: KPA = 1.00
# Instance 6032: KPA = 1.14
# Instance 5717: KPA = 0.57
# Instance 286: KPA = 1.14
# Instance 3189: KPA = 0.78
# Instance 1160: KPA = 1.20
# Instance 6194: KPA = 0.75
# Instance 4883: KPA = 1.00
# Instance 939: KPA = 0.55
# Instance 4300: KPA = 0.67
# Instance 3871: KPA = 0.75
# Instance 6244: KPA = 1.17
# Instance 3158: KPA = 0.80
# Instance 2138: KPA = 0.78
# Instance 1232: KPA = 0.88
# Instance 7254: KPA = 0.83
# Instance 1903: KPA = 0.71
# Instance 2217: KPA = 1.00
# Instance 3245: KPA = 0.80
# Instance 6912: KPA = 0.86
# Instance 5487: KPA = 1.20
# Instance 3173: KPA = 0.88
# Instance 2509: KPA = 1.17
# Instance 632: KPA = 0.67
# Instance 7269: KPA = 1.00
# Instance 5297: KPA = 0.88
# Instance 1591: KPA = 1.17
# Instance 561: KPA = 1.14
# Instance 5395: KPA = 0.88
# Instance 2349: KPA = 1.00
# Instance 516: KPA = 1.00
# Instance 1700: KPA = 1.00
# Instance 2810: KPA = 1.00
# Instance 2264: KPA = 1.00
# Instance 6087: KPA = 0.88
# Instance 2078: KPA = 1.00
# Instance 6153: KPA = 0.73
# Instance 275: KPA = 0.88
# Instance 4206: KPA = 1.00
# Instance 597: KPA = 1.00
# Instance 5653: KPA = 0.62
# Instance 3660: KPA = 0.67
# Instance 3177: KPA = 0.83
# Instance 689: KPA = 0.88
# Instance 5912: KPA = 1.00
# Instance 4402: KPA = 0.78
# Instance 4859: KPA = 0.83
# Instance 7078: KPA = 1.00
# Instance 7234: KPA = 1.00
# Instance 6889: KPA = 1.17
# Instance 7041: KPA = 1.33
# Instance 6311: KPA = 1.00
# Instance 6335: KPA = 1.00
# Instance 1539: KPA = 1.17
# Instance 7061: KPA = 1.12
# Instance 578: KPA = 0.75
# Instance 5439: KPA = 1.17
# Instance 4642: KPA = 0.57
# Instance 864: KPA = 0.67
# Instance 4816: KPA = 1.00
# Instance 2806: KPA = 1.00
# Instance 3083: KPA = 1.00
# Instance 3590: KPA = 1.14
# Instance 1959: KPA = 0.80
# Instance 1300: KPA = 0.50
# Instance 5428: KPA = 1.17
# Instance 7349: KPA = 0.86
# Instance 4365: KPA = 1.00
# Instance 5477: KPA = 0.55
# Instance 7595: KPA = 0.60
# Instance 3638: KPA = 0.83
# Instance 732: KPA = 1.00
# Instance 2795: KPA = 1.00
# Instance 7365: KPA = 0.83
# Instance 3496: KPA = 1.00
# Instance 4479: KPA = 0.80
# Instance 617: KPA = 0.78
# Instance 1702: KPA = 1.20
# Instance 5846: KPA = 1.14
# Instance 4946: KPA = 0.82
# Instance 3557: KPA = 1.25
# Instance 4201: KPA = 0.75
# Instance 5090: KPA = 1.00
# Instance 5934: KPA = 1.00
# Instance 6383: KPA = 1.00
# Instance 6805: KPA = 1.00
# Instance 2361: KPA = 0.80
# Instance 4002: KPA = 1.14
# Instance 7371: KPA = 0.91
# Instance 4989: KPA = 0.75
# Instance 2343: KPA = 0.40
# Instance 6111: KPA = 0.86
# Instance 851: KPA = 1.00
# Instance 1928: KPA = 1.00
# Instance 7619: KPA = 0.83
# Instance 3420: KPA = 1.14
# Instance 5448: KPA = 0.71
# Instance 6094: KPA = 0.86
# Instance 435: KPA = 1.00
# Instance 7361: KPA = 1.25
# Instance 5868: KPA = 0.88
# Instance 5853: KPA = 0.71
# Instance 309: KPA = 0.83
# Instance 6598: KPA = 0.83
# Instance 3835: KPA = 0.75
# Instance 607: KPA = 0.86
# Instance 2257: KPA = 1.12
# Instance 3666: KPA = 0.38
# Instance 6682: KPA = 1.17
# Instance 7494: KPA = 1.00
# Instance 3336: KPA = 1.00
# Average KPA = 0.92

# %%
def gold_path(instance, json_file):
    # Load the JSON file
    with open(json_file, 'r') as file:
        try:
            data = json.load(file)
            routes = data if isinstance(data, list) else [data]
        except json.JSONDecodeError as e:
            print(f"Error decoding JSON file: {e}")

    # Convert the list of dictionaries to a DataFrame
    df = pd.DataFrame(routes)

    # Specify the instance ID you want to look for
    target_instance_id = str(instance)  # Replace with the actual instance ID
    data = []
    data.insert(0, "Starting Point")
    # Explore every instance in the 'instances' column
    for index, row in df.iterrows():
        instances = row['instances']  # Get the instances dictionary

        if isinstance(instances, dict):
            if target_instance_id in instances:
                instance_data = instances[target_instance_id]

                # Access the gold navigation lines
                gold_navigation_lines = instance_data.get('gold_navigation_lines', [])

                # Ensure gold_navigation_lines is a list
                if isinstance(gold_navigation_lines, list):
                    # Initialize a list to store output lines
                    output_lines = []

                    # Loop through the navigation lines
                    for i, line in enumerate(gold_navigation_lines):
                        # Skip lines containing "stop"
                        if "stop" in line.strip().lower():
                            line=""
                            break

                        # Replace lines containing 'intersection' with 'Intersection'
                        #if 'intersection' in line.lower():
                         #   line = 'Intersection'

                        # Print the first line
                        if i == 0:
                            output_lines.append(line)  # Print the first line

                        # Check if the line does not start with '- n.' where n is a number
                        if not re.match(r'^\s*\d+\.', line):
                            output_lines.append(line)  # Add the line without the match

                            # Check if there's a next line and add it
                            if i + 1 < len(gold_navigation_lines):
                                output_lines.append(gold_navigation_lines[i + 1])  # Add the next line

                    # Print the selected lines
                    for line in output_lines:
                        data.append(line)  # Collect output lines in data
                    #print(data)
                else:
                    print(f"Instance ID {target_instance_id} does not contain valid navigation lines.")
                break  # Exit after finding the target instance
        else:
            print(f"Row {index} does not contain a valid instances dictionary.")
    data.insert(-1, "Target")

    # Initialize lists to hold places and actions
    places = []
    actions = []

    # Iterate through the data and classify each entry
    for entry in data:
        if re.match(r'^\d+\.\s*(forward|right|left|stop)', entry):  # Match actions
            actions.append(entry.split('. ')[1])  # Add only the action (no number)
        else:
            # Replace unwanted phrases and clean the entry
            cleaned_entry = re.sub(r' slightly right\.| ahead\.| slightly left\.|There is a | on your left\.| on your right\.', '', entry)
            # Check if the cleaned entry has at most 2 words
            if len(cleaned_entry.split()) <= 5:
                places.append(cleaned_entry)  # Add cleaned entry to places

    # Remove duplicates while retaining the first occurrence and ensuring "Intersection" is included
    unique_places = []
    unique_actions = []

    for i in range(len(places)):
        place = places[i]
        action = actions[i] if i < len(actions) else None


        # Check if the place is "Intersection" or not already in unique_places
        if "Intersection" in place or "intersection" in place:
            unique_places.append(place)
            if action:
              unique_actions.append(action)
        elif place not in unique_places:  # Corrected condition
            unique_places.append(place)
            if action:
              unique_actions.append(action)
    # Output the separated lists
    return unique_places#, unique_actions

    # Example usage
json_file_path = "/content/dev_results.json"  # Replace with your file path
instance_id_to_search = "6918"
node_gold =  gold_path(instance_id_to_search, json_file_path)

# Print the combined lines
for line in node_gold:
    print(line)
# Out:
# Starting Point
# Project Cozy
# 3-way intersection. Project Cozy
# 4-way intersection.
# 4-way intersection.
# 4-way intersection.
# 4-way intersection.
# Target

# %%
import json
import pandas as pd

def predicted_path(predict_instance, predicted_file):

    # Load the JSON file
    with open(predicted_file, 'r') as file:
        try:
            data = json.load(file)
        except json.JSONDecodeError as e:
            print(f"Error decoding JSON file: {e}")
            return [], []

    # Convert JSON data to DataFrame
    df = pd.DataFrame(data)

    # Search for the matching instance ID
    matching_row = df[df["Instance_id"] == int(predict_instance)]

    if matching_row.empty:
        print(f"No matching instance found for ID: {predict_instance}")
        return [], []

    # Extract the graph data
    graph_list = matching_row.iloc[0]["Graph"]

    # Initialize lists for nodes and actions
    nodes = []
    my_actions = []

    if isinstance(graph_list, dict):
        nodes = [node.title() for node in graph_list.get('Nodes', {}).values()]
        edges = graph_list.get('Edges', [])
        my_actions = [edge.get('action', '').lower() for edge in edges]

    # Define valid actions in lowercase
    valid_actions = ["forward", "left", "right", "stop"]

    # Replace invalid actions with "forward"
    my_actions = [action if action in valid_actions else "forward" for action in my_actions]

    # Clean the nodes
    cleaned_nodes = [
        "Target" if any(key.lower() in node.lower() for key in ["target", "(target)"])
        #else "Intersection" if any(key.lower() in node.lower() for key in ["intersection", "light", "4-way stop", "t-intersection", "lights", "junction"])
        else node.replace("T-Intersection", "3-Way Intersection").strip().title()
        for node in nodes
    ]
    new_nodes = []
    for my_node in cleaned_nodes:
        if "Target" in my_node:  # Check if "Target" is in the node
            my_node = my_node.replace("()", "").strip()  # Remove "(Target)" and clean spaces
            # Add the modified node only if it's not empty
            if my_node != "":
                new_nodes.append(my_node)  # Add the modified node
        else:
            new_nodes.append(my_node)  # Add the node as is

    # Remove the last node if it exists
    #if new_nodes:
     #   new_nodes.pop()
    #cleaned_nodes = new_nodes


    return cleaned_nodes#, my_actions

# Path to your JSON file
json_file_predict = "/content/cleaned_cognitive_map_cost.json"

# Specify the instance ID to search for
instance_id_to_search = "6918"

# Get predicted nodes and actions
node_predict = predicted_path(instance_id_to_search, json_file_predict)

# Print the cleaned nodes and actions
print("\nNodes:")
for line_node in node_predict:
    print(line_node)
# Out:
# Nodes:
# Starting Point, Parking
# Project Cozy
# Intersection, Parking
# 3-Way Intersection, Mille Miglia
# Intersection
# 4-Way Intersection, Laundromat
# 4-Way Intersection
# Bagel Shop
# Target

# %%
# Path to your JSON file
json_file_predict = '/content/cleaned_cognitive_map_cost.json'
# Path to your JSON file
json_file_GT = '/content/dev_results.json'

# Load the JSON file
with open(json_file_predict, 'r') as file:
    try:
        # Load the entire JSON content
        data = json.load(file)
        # Ensure the data is a list of dictionaries
        routes = data if isinstance(data, list) else [data]
    except json.JSONDecodeError as e:
        print(f"Error decoding JSON file: {e}")
        routes = []

# Convert the list of dictionaries to a DataFrame
df = pd.DataFrame(routes)

# Initialize dictionaries
all_predicted_nodes = {}
all_gold_nodes = {}

# Loop over each graph instance
for i in range(0, 200):
    instance_id = df.loc[i, 'Instance_id']

    # Get Ground Truth nodes
    node_GT = gold_path(instance_id, json_file_GT)

    # Get predicted nodes
    node_predict = predicted_path(instance_id, json_file_predict)

    # Store results in dictionaries
    all_predicted_nodes[instance_id] = node_predict
    all_gold_nodes[instance_id] = node_GT

# %% [markdown]
# Shortest Path Distance (SPD)

# %%
def find_target_index(path, target_label='Target'):
    """
    Find the index of a node containing the word 'Target' in the path.
    Returns -1 if not found.
    """
    for idx, node in enumerate(path):
        # If node is a list (multiple labels), join it into a string
        node_str = ' '.join(node) if isinstance(node, list) else node

        # Check if target_label is in the node name (case-insensitive)
        if target_label.lower() in node_str.lower():
            return idx  # Found, return the index

    return -1  # Not found

def compare_target_index(predicted_path, gold_path):
    """
    Compare the index of the target node in predicted path to the length of the gold path.
    Returns a dictionary with target indexes, index difference, and progress ratio.
    """
    # Search for target indices
    target_index_predicted = find_target_index(predicted_path)
    target_index_gold = abs(find_target_index(gold_path))

    # Initialize with default values
    index_difference = float('inf')
    progress_ratio = 0.0

    # Handle case where target is found in the predicted path
    if target_index_predicted == -1:
      target_index_predicted = len(predicted_path)
    if target_index_predicted != -1:
        index_difference = abs(target_index_predicted - target_index_gold)

        # Avoid division by zero
        if len(predicted_path) > 0:
            ratio_spd = abs(index_difference/len(predicted_path))

    # Print diagnostic info
    print(f"Predicted Target Index: {target_index_predicted}")
    print(f"Gold Target Index: {target_index_gold}")
    print(f"Index Difference (SPD proxy): {index_difference}")
    print(f"Ratio SPD: {ratio_spd:.2f}")

    return {
        'target_index_predicted': target_index_predicted,
        'target_index_gold': target_index_gold,
        'index_difference': index_difference,
        'ratio_spd': ratio_spd
    }


# Store all SPD-like index differences
spd_scores = {}

# Loop through all instances in your data
for instance_id in all_predicted_nodes.keys():
    predicted_path = all_predicted_nodes[instance_id]
    gold_path = all_gold_nodes[instance_id]

    # Run the target index comparison for each instance
    comparison = compare_target_index(predicted_path, gold_path)

    # Grab the SPD-like index difference
    spd = comparison['ratio_spd']

    # Store it in the dictionary with the instance_id
    spd_scores[instance_id] = spd

    print(f"Instance {instance_id}: SPD (index difference) = {spd}")

# Calculate average SPD
if spd_scores:
    total_spd = sum(spd_scores.values())
    avg_spd = total_spd / len(spd_scores)
    print(f"\nAverage SPD (index difference) over {len(spd_scores)} instances: {avg_spd:.2f}")
else:
    print("No SPD scores calculated.")
# Out:
# Predicted Target Index: 8
# Gold Target Index: 7
# Index Difference (SPD proxy): 1
# Ratio SPD: 0.11
# Instance 6918: SPD (index difference) = 0.1111111111111111
# Predicted Target Index: 6
# Gold Target Index: 6
# Index Difference (SPD proxy): 0
# Ratio SPD: 0.00
# Instance 990: SPD (index difference) = 0.0
# Predicted Target Index: 9
# Gold Target Index: 12
# Index Difference (SPD proxy): 3
# Ratio SPD: 0.30
# Instance 1017: SPD (index difference) = 0.3
# Predicted Target Index: 6
# Gold Target Index: 7
# Index Difference (SPD proxy): 1
# Ratio SPD: 0.14
# Instance 5947: SPD (index difference) = 0.14285714285714285
# Predicted Target Index: 11
# Gold Target Index: 10
# Index Difference (SPD proxy): 1
# Ratio SPD: 0.08
# Instance 6503: SPD (index difference) = 0.08333333333333333
# Predicted Target Index: 4
# Gold Target Index: 7
# Index Difference (SPD proxy): 3
# Ratio SPD: 0.60
# Instance 1681: SPD (index difference) = 0.6
# Predicted Target Index: 8
# Gold Target Index: 8
# Index Difference (SPD proxy): 0
# Ratio SPD: 0.00
# Instance 5327: SPD (index difference) = 0.0
# Predicted Target Index: 8
# Gold Target Index: 7
# Index Difference (SPD proxy): 1
# Ratio SPD: 0.11
# Instance 6960: SPD (index difference) = 0.1111111111111111
# Predicted Target Index: 5
# Gold Target Index: 4
# Index Difference (SPD proxy): 1
# Ratio SPD: 0.17
# Instance 2663: SPD (index difference) = 0.16666666666666666
# Predicted Target Index: 6
# Gold Target Index: 5
# Index Difference (SPD proxy): 1
# Ratio SPD: 0.14
# Instance 6696: SPD (index difference) = 0.14285714285714285
# Predicted Target Index: 4
# Gold Target Index: 6
# Index Difference (SPD proxy): 2
# Ratio SPD: 0.40
# Instance 993: SPD (index difference) = 0.4
# Predicted Target Index: 7
# Gold Target Index: 7
# Index Difference (SPD proxy): 0
# Ratio SPD: 0.00
# Instance 1994: SPD (index difference) = 0.0
# Predicted Target Index: 8
# Gold Target Index: 8
# Index Difference (SPD proxy): 0
# Ratio SPD: 0.00
# Instance 4552: SPD (index difference) = 0.0
# Predicted Target Index: 6
# Gold Target Index: 10
# Index Difference (SPD proxy): 4
# Ratio SPD: 0.57
# Instance 2840: SPD (index difference) = 0.5714285714285714
# Predicted Target Index: 5
# Gold Target Index: 8
# Index Difference (SPD proxy): 3
# Ratio SPD: 0.50
# Instance 96: SPD (index difference) = 0.5
# Predicted Target Index: 5
# Gold Target Index: 4
# Index Difference (SPD proxy): 1
# Ratio SPD: 0.17
# Instance 1966: SPD (index difference) = 0.16666666666666666
# Predicted Target Index: 7
# Gold Target Index: 8
# Index Difference (SPD proxy): 1
# Ratio SPD: 0.12
# Instance 6825: SPD (index difference) = 0.125
# Predicted Target Index: 9
# Gold Target Index: 6
# Index Difference (SPD proxy): 3
# Ratio SPD: 0.30
# Instance 5180: SPD (index difference) = 0.3
# Predicted Target Index: 9
# Gold Target Index: 10
# Index Difference (SPD proxy): 1
# Ratio SPD: 0.10
# Instance 5807: SPD (index difference) = 0.1
# Predicted Target Index: 6
# Gold Target Index: 6
# Index Difference (SPD proxy): 0
# Ratio SPD: 0.00
# Instance 2879: SPD (index difference) = 0.0
# Predicted Target Index: 5
# Gold Target Index: 7
# Index Difference (SPD proxy): 2
# Ratio SPD: 0.33
# Instance 3513: SPD (index difference) = 0.3333333333333333
# Predicted Target Index: 7
# Gold Target Index: 4
# Index Difference (SPD proxy): 3
# Ratio SPD: 0.38
# Instance 4806: SPD (index difference) = 0.375
# Predicted Target Index: 7
# Gold Target Index: 8
# Index Difference (SPD proxy): 1
# Ratio SPD: 0.12
# Instance 4693: SPD (index difference) = 0.125
# Predicted Target Index: 9
# Gold Target Index: 12
# Index Difference (SPD proxy): 3
# Ratio SPD: 0.30
# Instance 2523: SPD (index difference) = 0.3
# Predicted Target Index: 9
# Gold Target Index: 7
# Index Difference (SPD proxy): 2
# Ratio SPD: 0.20
# Instance 5087: SPD (index difference) = 0.2
# Predicted Target Index: 9
# Gold Target Index: 7
# Index Difference (SPD proxy): 2
# Ratio SPD: 0.20
# Instance 5856: SPD (index difference) = 0.2
# Predicted Target Index: 8
# Gold Target Index: 7
# Index Difference (SPD proxy): 1
# Ratio SPD: 0.11
# Instance 6700: SPD (index difference) = 0.1111111111111111
# Predicted Target Index: 7
# Gold Target Index: 8
# Index Difference (SPD proxy): 1
# Ratio SPD: 0.12
# Instance 2946: SPD (index difference) = 0.125
# Predicted Target Index: 6
# Gold Target Index: 7
# Index Difference (SPD proxy): 1
# Ratio SPD: 0.14
# Instance 1921: SPD (index difference) = 0.14285714285714285
# Predicted Target Index: 9
# Gold Target Index: 8
# Index Difference (SPD proxy): 1
# Ratio SPD: 0.10
# Instance 1939: SPD (index difference) = 0.1
# Predicted Target Index: 7
# Gold Target Index: 7
# Index Difference (SPD proxy): 0
# Ratio SPD: 0.00
# Instance 3997: SPD (index difference) = 0.0
# Predicted Target Index: 9
# Gold Target Index: 8
# Index Difference (SPD proxy): 1
# Ratio SPD: 0.10
# Instance 5523: SPD (index difference) = 0.1
# Predicted Target Index: 7
# Gold Target Index: 6
# Index Difference (SPD proxy): 1
# Ratio SPD: 0.12
# Instance 5197: SPD (index difference) = 0.125
# Predicted Target Index: 8
# Gold Target Index: 8
# Index Difference (SPD proxy): 0
# Ratio SPD: 0.00
# Instance 1570: SPD (index difference) = 0.0
# Predicted Target Index: 7
# Gold Target Index: 6
# Index Difference (SPD proxy): 1
# Ratio SPD: 0.12
# Instance 2045: SPD (index difference) = 0.125
# Predicted Target Index: 8
# Gold Target Index: 9
# Index Difference (SPD proxy): 1
# Ratio SPD: 0.11
# Instance 3062: SPD (index difference) = 0.1111111111111111
# Predicted Target Index: 5
# Gold Target Index: 6
# Index Difference (SPD proxy): 1
# Ratio SPD: 0.17
# Instance 1047: SPD (index difference) = 0.16666666666666666
# Predicted Target Index: 8
# Gold Target Index: 7
# Index Difference (SPD proxy): 1
# Ratio SPD: 0.11
# Instance 5783: SPD (index difference) = 0.1111111111111111
# Predicted Target Index: 7
# Gold Target Index: 6
# Index Difference (SPD proxy): 1
# Ratio SPD: 0.12
# Instance 3279: SPD (index difference) = 0.125
# Predicted Target Index: 8
# Gold Target Index: 6
# Index Difference (SPD proxy): 2
# Ratio SPD: 0.22
# Instance 2322: SPD (index difference) = 0.2222222222222222
# Predicted Target Index: 6
# Gold Target Index: 7
# Index Difference (SPD proxy): 1
# Ratio SPD: 0.14
# Instance 6211: SPD (index difference) = 0.14285714285714285
# Predicted Target Index: 7
# Gold Target Index: 7
# Index Difference (SPD proxy): 0
# Ratio SPD: 0.00
# Instance 6633: SPD (index difference) = 0.0
# Predicted Target Index: 6
# Gold Target Index: 7
# Index Difference (SPD proxy): 1
# Ratio SPD: 0.14
# Instance 4162: SPD (index difference) = 0.14285714285714285
# Predicted Target Index: 5
# Gold Target Index: 5
# Index Difference (SPD proxy): 0
# Ratio SPD: 0.00
# Instance 344: SPD (index difference) = 0.0
# Predicted Target Index: 6
# Gold Target Index: 5
# Index Difference (SPD proxy): 1
# Ratio SPD: 0.14
# Instance 228: SPD (index difference) = 0.14285714285714285
# Predicted Target Index: 10
# Gold Target Index: 3
# Index Difference (SPD proxy): 7
# Ratio SPD: 0.64
# Instance 6679: SPD (index difference) = 0.6363636363636364
# Predicted Target Index: 6
# Gold Target Index: 5
# Index Difference (SPD proxy): 1
# Ratio SPD: 0.14
# Instance 3608: SPD (index difference) = 0.14285714285714285
# Predicted Target Index: 6
# Gold Target Index: 6
# Index Difference (SPD proxy): 0
# Ratio SPD: 0.00
# Instance 5644: SPD (index difference) = 0.0
# Predicted Target Index: 7
# Gold Target Index: 6
# Index Difference (SPD proxy): 1
# Ratio SPD: 0.12
# Instance 5265: SPD (index difference) = 0.125
# Predicted Target Index: 7
# Gold Target Index: 8
# Index Difference (SPD proxy): 1
# Ratio SPD: 0.12
# Instance 2798: SPD (index difference) = 0.125
# Predicted Target Index: 4
# Gold Target Index: 5
# Index Difference (SPD proxy): 1
# Ratio SPD: 0.20
# Instance 1780: SPD (index difference) = 0.2
# Predicted Target Index: 8
# Gold Target Index: 9
# Index Difference (SPD proxy): 1
# Ratio SPD: 0.11
# Instance 6626: SPD (index difference) = 0.1111111111111111
# Predicted Target Index: 9
# Gold Target Index: 10
# Index Difference (SPD proxy): 1
# Ratio SPD: 0.10
# Instance 2172: SPD (index difference) = 0.1
# Predicted Target Index: 6
# Gold Target Index: 7
# Index Difference (SPD proxy): 1
# Ratio SPD: 0.14
# Instance 5573: SPD (index difference) = 0.14285714285714285
# Predicted Target Index: 6
# Gold Target Index: 7
# Index Difference (SPD proxy): 1
# Ratio SPD: 0.14
# Instance 3319: SPD (index difference) = 0.14285714285714285
# Predicted Target Index: 6
# Gold Target Index: 7
# Index Difference (SPD proxy): 1
# Ratio SPD: 0.14
# Instance 4320: SPD (index difference) = 0.14285714285714285
# Predicted Target Index: 7
# Gold Target Index: 8
# Index Difference (SPD proxy): 1
# Ratio SPD: 0.12
# Instance 7358: SPD (index difference) = 0.125
# Predicted Target Index: 9
# Gold Target Index: 10
# Index Difference (SPD proxy): 1
# Ratio SPD: 0.10
# Instance 6931: SPD (index difference) = 0.1
# Predicted Target Index: 5
# Gold Target Index: 8
# Index Difference (SPD proxy): 3
# Ratio SPD: 0.50
# Instance 2680: SPD (index difference) = 0.5
# Predicted Target Index: 4
# Gold Target Index: 6
# Index Difference (SPD proxy): 2
# Ratio SPD: 0.40
# Instance 2484: SPD (index difference) = 0.4
# Predicted Target Index: 7
# Gold Target Index: 6
# Index Difference (SPD proxy): 1
# Ratio SPD: 0.12
# Instance 5940: SPD (index difference) = 0.125
# Predicted Target Index: 6
# Gold Target Index: 9
# Index Difference (SPD proxy): 3
# Ratio SPD: 0.43
# Instance 2832: SPD (index difference) = 0.42857142857142855
# Predicted Target Index: 7
# Gold Target Index: 7
# Index Difference (SPD proxy): 0
# Ratio SPD: 0.00
# Instance 1433: SPD (index difference) = 0.0
# Predicted Target Index: 10
# Gold Target Index: 7
# Index Difference (SPD proxy): 3
# Ratio SPD: 0.27
# Instance 5638: SPD (index difference) = 0.2727272727272727
# Predicted Target Index: 6
# Gold Target Index: 10
# Index Difference (SPD proxy): 4
# Ratio SPD: 0.57
# Instance 4868: SPD (index difference) = 0.5714285714285714
# Predicted Target Index: 6
# Gold Target Index: 8
# Index Difference (SPD proxy): 2
# Ratio SPD: 0.29
# Instance 2403: SPD (index difference) = 0.2857142857142857
# Predicted Target Index: 7
# Gold Target Index: 7
# Index Difference (SPD proxy): 0
# Ratio SPD: 0.00
# Instance 571: SPD (index difference) = 0.0
# Predicted Target Index: 7
# Gold Target Index: 7
# Index Difference (SPD proxy): 0
# Ratio SPD: 0.00
# Instance 164: SPD (index difference) = 0.0
# Predicted Target Index: 6
# Gold Target Index: 9
# Index Difference (SPD proxy): 3
# Ratio SPD: 0.43
# Instance 5894: SPD (index difference) = 0.42857142857142855
# Predicted Target Index: 9
# Gold Target Index: 8
# Index Difference (SPD proxy): 1
# Ratio SPD: 0.10
# Instance 4238: SPD (index difference) = 0.1
# Predicted Target Index: 10
# Gold Target Index: 8
# Index Difference (SPD proxy): 2
# Ratio SPD: 0.18
# Instance 4548: SPD (index difference) = 0.18181818181818182
# Predicted Target Index: 7
# Gold Target Index: 5
# Index Difference (SPD proxy): 2
# Ratio SPD: 0.25
# Instance 4260: SPD (index difference) = 0.25
# Predicted Target Index: 5
# Gold Target Index: 6
# Index Difference (SPD proxy): 1
# Ratio SPD: 0.14
# Instance 5731: SPD (index difference) = 0.14285714285714285
# Predicted Target Index: 6
# Gold Target Index: 6
# Index Difference (SPD proxy): 0
# Ratio SPD: 0.00
# Instance 5147: SPD (index difference) = 0.0
# Predicted Target Index: 8
# Gold Target Index: 10
# Index Difference (SPD proxy): 2
# Ratio SPD: 0.22
# Instance 7291: SPD (index difference) = 0.2222222222222222
# Predicted Target Index: 6
# Gold Target Index: 8
# Index Difference (SPD proxy): 2
# Ratio SPD: 0.29
# Instance 4377: SPD (index difference) = 0.2857142857142857
# Predicted Target Index: 5
# Gold Target Index: 7
# Index Difference (SPD proxy): 2
# Ratio SPD: 0.33
# Instance 1708: SPD (index difference) = 0.3333333333333333
# Predicted Target Index: 8
# Gold Target Index: 6
# Index Difference (SPD proxy): 2
# Ratio SPD: 0.22
# Instance 1259: SPD (index difference) = 0.2222222222222222
# Predicted Target Index: 6
# Gold Target Index: 6
# Index Difference (SPD proxy): 0
# Ratio SPD: 0.00
# Instance 2291: SPD (index difference) = 0.0
# Predicted Target Index: 5
# Gold Target Index: 7
# Index Difference (SPD proxy): 2
# Ratio SPD: 0.33
# Instance 5479: SPD (index difference) = 0.3333333333333333
# Predicted Target Index: 6
# Gold Target Index: 5
# Index Difference (SPD proxy): 1
# Ratio SPD: 0.14
# Instance 6338: SPD (index difference) = 0.14285714285714285
# Predicted Target Index: 4
# Gold Target Index: 7
# Index Difference (SPD proxy): 3
# Ratio SPD: 0.60
# Instance 5218: SPD (index difference) = 0.6
# Predicted Target Index: 9
# Gold Target Index: 9
# Index Difference (SPD proxy): 0
# Ratio SPD: 0.00
# Instance 7110: SPD (index difference) = 0.0
# Predicted Target Index: 8
# Gold Target Index: 9
# Index Difference (SPD proxy): 1
# Ratio SPD: 0.11
# Instance 2624: SPD (index difference) = 0.1111111111111111
# Predicted Target Index: 7
# Gold Target Index: 7
# Index Difference (SPD proxy): 0
# Ratio SPD: 0.00
# Instance 6329: SPD (index difference) = 0.0
# Predicted Target Index: 8
# Gold Target Index: 9
# Index Difference (SPD proxy): 1
# Ratio SPD: 0.11
# Instance 5467: SPD (index difference) = 0.1111111111111111
# Predicted Target Index: 7
# Gold Target Index: 8
# Index Difference (SPD proxy): 1
# Ratio SPD: 0.12
# Instance 5568: SPD (index difference) = 0.125
# Predicted Target Index: 7
# Gold Target Index: 10
# Index Difference (SPD proxy): 3
# Ratio SPD: 0.38
# Instance 7369: SPD (index difference) = 0.375
# Predicted Target Index: 7
# Gold Target Index: 9
# Index Difference (SPD proxy): 2
# Ratio SPD: 0.25
# Instance 1709: SPD (index difference) = 0.25
# Predicted Target Index: 5
# Gold Target Index: 5
# Index Difference (SPD proxy): 0
# Ratio SPD: 0.00
# Instance 3184: SPD (index difference) = 0.0
# Predicted Target Index: 7
# Gold Target Index: 7
# Index Difference (SPD proxy): 0
# Ratio SPD: 0.00
# Instance 6032: SPD (index difference) = 0.0
# Predicted Target Index: 8
# Gold Target Index: 8
# Index Difference (SPD proxy): 0
# Ratio SPD: 0.00
# Instance 5717: SPD (index difference) = 0.0
# Predicted Target Index: 7
# Gold Target Index: 7
# Index Difference (SPD proxy): 0
# Ratio SPD: 0.00
# Instance 286: SPD (index difference) = 0.0
# Predicted Target Index: 9
# Gold Target Index: 9
# Index Difference (SPD proxy): 0
# Ratio SPD: 0.00
# Instance 3189: SPD (index difference) = 0.0
# Predicted Target Index: 5
# Gold Target Index: 5
# Index Difference (SPD proxy): 0
# Ratio SPD: 0.00
# Instance 1160: SPD (index difference) = 0.0
# Predicted Target Index: 7
# Gold Target Index: 8
# Index Difference (SPD proxy): 1
# Ratio SPD: 0.12
# Instance 6194: SPD (index difference) = 0.125
# Predicted Target Index: 8
# Gold Target Index: 9
# Index Difference (SPD proxy): 1
# Ratio SPD: 0.11
# Instance 4883: SPD (index difference) = 0.1111111111111111
# Predicted Target Index: 6
# Gold Target Index: 10
# Index Difference (SPD proxy): 4
# Ratio SPD: 0.57
# Instance 939: SPD (index difference) = 0.5714285714285714
# Predicted Target Index: 6
# Gold Target Index: 9
# Index Difference (SPD proxy): 3
# Ratio SPD: 0.43
# Instance 4300: SPD (index difference) = 0.42857142857142855
# Predicted Target Index: 8
# Gold Target Index: 8
# Index Difference (SPD proxy): 0
# Ratio SPD: 0.00
# Instance 3871: SPD (index difference) = 0.0
# Predicted Target Index: 7
# Gold Target Index: 6
# Index Difference (SPD proxy): 1
# Ratio SPD: 0.12
# Instance 6244: SPD (index difference) = 0.125
# Predicted Target Index: 8
# Gold Target Index: 10
# Index Difference (SPD proxy): 2
# Ratio SPD: 0.22
# Instance 3158: SPD (index difference) = 0.2222222222222222
# Predicted Target Index: 7
# Gold Target Index: 6
# Index Difference (SPD proxy): 1
# Ratio SPD: 0.12
# Instance 2138: SPD (index difference) = 0.125
# Predicted Target Index: 6
# Gold Target Index: 8
# Index Difference (SPD proxy): 2
# Ratio SPD: 0.29
# Instance 1232: SPD (index difference) = 0.2857142857142857
# Predicted Target Index: 4
# Gold Target Index: 6
# Index Difference (SPD proxy): 2
# Ratio SPD: 0.29
# Instance 7254: SPD (index difference) = 0.2857142857142857
# Predicted Target Index: 9
# Gold Target Index: 7
# Index Difference (SPD proxy): 2
# Ratio SPD: 0.20
# Instance 1903: SPD (index difference) = 0.2
# Predicted Target Index: 6
# Gold Target Index: 6
# Index Difference (SPD proxy): 0
# Ratio SPD: 0.00
# Instance 2217: SPD (index difference) = 0.0
# Predicted Target Index: 5
# Gold Target Index: 5
# Index Difference (SPD proxy): 0
# Ratio SPD: 0.00
# Instance 3245: SPD (index difference) = 0.0
# Predicted Target Index: 5
# Gold Target Index: 7
# Index Difference (SPD proxy): 2
# Ratio SPD: 0.33
# Instance 6912: SPD (index difference) = 0.3333333333333333
# Predicted Target Index: 7
# Gold Target Index: 5
# Index Difference (SPD proxy): 2
# Ratio SPD: 0.25
# Instance 5487: SPD (index difference) = 0.25
# Predicted Target Index: 7
# Gold Target Index: 8
# Index Difference (SPD proxy): 1
# Ratio SPD: 0.12
# Instance 3173: SPD (index difference) = 0.125
# Predicted Target Index: 8
# Gold Target Index: 6
# Index Difference (SPD proxy): 2
# Ratio SPD: 0.22
# Instance 2509: SPD (index difference) = 0.2222222222222222
# Predicted Target Index: 5
# Gold Target Index: 6
# Index Difference (SPD proxy): 1
# Ratio SPD: 0.17
# Instance 632: SPD (index difference) = 0.16666666666666666
# Predicted Target Index: 8
# Gold Target Index: 10
# Index Difference (SPD proxy): 2
# Ratio SPD: 0.22
# Instance 7269: SPD (index difference) = 0.2222222222222222
# Predicted Target Index: 8
# Gold Target Index: 8
# Index Difference (SPD proxy): 0
# Ratio SPD: 0.00
# Instance 5297: SPD (index difference) = 0.0
# Predicted Target Index: 6
# Gold Target Index: 6
# Index Difference (SPD proxy): 0
# Ratio SPD: 0.00
# Instance 1591: SPD (index difference) = 0.0
# Predicted Target Index: 7
# Gold Target Index: 7
# Index Difference (SPD proxy): 0
# Ratio SPD: 0.00
# Instance 561: SPD (index difference) = 0.0
# Predicted Target Index: 10
# Gold Target Index: 8
# Index Difference (SPD proxy): 2
# Ratio SPD: 0.18
# Instance 5395: SPD (index difference) = 0.18181818181818182
# Predicted Target Index: 5
# Gold Target Index: 6
# Index Difference (SPD proxy): 1
# Ratio SPD: 0.17
# Instance 2349: SPD (index difference) = 0.16666666666666666
# Predicted Target Index: 6
# Gold Target Index: 7
# Index Difference (SPD proxy): 1
# Ratio SPD: 0.14
# Instance 516: SPD (index difference) = 0.14285714285714285
# Predicted Target Index: 5
# Gold Target Index: 6
# Index Difference (SPD proxy): 1
# Ratio SPD: 0.17
# Instance 1700: SPD (index difference) = 0.16666666666666666
# Predicted Target Index: 5
# Gold Target Index: 5
# Index Difference (SPD proxy): 0
# Ratio SPD: 0.00
# Instance 2810: SPD (index difference) = 0.0
# Predicted Target Index: 5
# Gold Target Index: 6
# Index Difference (SPD proxy): 1
# Ratio SPD: 0.17
# Instance 2264: SPD (index difference) = 0.16666666666666666
# Predicted Target Index: 7
# Gold Target Index: 8
# Index Difference (SPD proxy): 1
# Ratio SPD: 0.12
# Instance 6087: SPD (index difference) = 0.125
# Predicted Target Index: 4
# Gold Target Index: 5
# Index Difference (SPD proxy): 1
# Ratio SPD: 0.20
# Instance 2078: SPD (index difference) = 0.2
# Predicted Target Index: 8
# Gold Target Index: 12
# Index Difference (SPD proxy): 4
# Ratio SPD: 0.44
# Instance 6153: SPD (index difference) = 0.4444444444444444
# Predicted Target Index: 6
# Gold Target Index: 8
# Index Difference (SPD proxy): 2
# Ratio SPD: 0.29
# Instance 275: SPD (index difference) = 0.2857142857142857
# Predicted Target Index: 7
# Gold Target Index: 1
# Index Difference (SPD proxy): 6
# Ratio SPD: 0.75
# Instance 4206: SPD (index difference) = 0.75
# Predicted Target Index: 7
# Gold Target Index: 7
# Index Difference (SPD proxy): 0
# Ratio SPD: 0.00
# Instance 597: SPD (index difference) = 0.0
# Predicted Target Index: 6
# Gold Target Index: 8
# Index Difference (SPD proxy): 2
# Ratio SPD: 0.29
# Instance 5653: SPD (index difference) = 0.2857142857142857
# Predicted Target Index: 6
# Gold Target Index: 9
# Index Difference (SPD proxy): 3
# Ratio SPD: 0.43
# Instance 3660: SPD (index difference) = 0.42857142857142855
# Predicted Target Index: 8
# Gold Target Index: 7
# Index Difference (SPD proxy): 1
# Ratio SPD: 0.11
# Instance 3177: SPD (index difference) = 0.1111111111111111
# Predicted Target Index: 7
# Gold Target Index: 8
# Index Difference (SPD proxy): 1
# Ratio SPD: 0.12
# Instance 689: SPD (index difference) = 0.125
# Predicted Target Index: 6
# Gold Target Index: 7
# Index Difference (SPD proxy): 1
# Ratio SPD: 0.14
# Instance 5912: SPD (index difference) = 0.14285714285714285
# Predicted Target Index: 8
# Gold Target Index: 9
# Index Difference (SPD proxy): 1
# Ratio SPD: 0.11
# Instance 4402: SPD (index difference) = 0.1111111111111111
# Predicted Target Index: 6
# Gold Target Index: 6
# Index Difference (SPD proxy): 0
# Ratio SPD: 0.00
# Instance 4859: SPD (index difference) = 0.0
# Predicted Target Index: 9
# Gold Target Index: 10
# Index Difference (SPD proxy): 1
# Ratio SPD: 0.10
# Instance 7078: SPD (index difference) = 0.1
# Predicted Target Index: 7
# Gold Target Index: 6
# Index Difference (SPD proxy): 1
# Ratio SPD: 0.12
# Instance 7234: SPD (index difference) = 0.125
# Predicted Target Index: 6
# Gold Target Index: 6
# Index Difference (SPD proxy): 0
# Ratio SPD: 0.00
# Instance 6889: SPD (index difference) = 0.0
# Predicted Target Index: 9
# Gold Target Index: 6
# Index Difference (SPD proxy): 3
# Ratio SPD: 0.30
# Instance 7041: SPD (index difference) = 0.3
# Predicted Target Index: 7
# Gold Target Index: 6
# Index Difference (SPD proxy): 1
# Ratio SPD: 0.12
# Instance 6311: SPD (index difference) = 0.125
# Predicted Target Index: 8
# Gold Target Index: 7
# Index Difference (SPD proxy): 1
# Ratio SPD: 0.11
# Instance 6335: SPD (index difference) = 0.1111111111111111
# Predicted Target Index: 7
# Gold Target Index: 6
# Index Difference (SPD proxy): 1
# Ratio SPD: 0.12
# Instance 1539: SPD (index difference) = 0.125
# Predicted Target Index: 9
# Gold Target Index: 9
# Index Difference (SPD proxy): 0
# Ratio SPD: 0.00
# Instance 7061: SPD (index difference) = 0.0
# Predicted Target Index: 6
# Gold Target Index: 8
# Index Difference (SPD proxy): 2
# Ratio SPD: 0.29
# Instance 578: SPD (index difference) = 0.2857142857142857
# Predicted Target Index: 7
# Gold Target Index: 6
# Index Difference (SPD proxy): 1
# Ratio SPD: 0.12
# Instance 5439: SPD (index difference) = 0.125
# Predicted Target Index: 6
# Gold Target Index: 7
# Index Difference (SPD proxy): 1
# Ratio SPD: 0.14
# Instance 4642: SPD (index difference) = 0.14285714285714285
# Predicted Target Index: 6
# Gold Target Index: 7
# Index Difference (SPD proxy): 1
# Ratio SPD: 0.14
# Instance 864: SPD (index difference) = 0.14285714285714285
# Predicted Target Index: 11
# Gold Target Index: 9
# Index Difference (SPD proxy): 2
# Ratio SPD: 0.17
# Instance 4816: SPD (index difference) = 0.16666666666666666
# Predicted Target Index: 7
# Gold Target Index: 7
# Index Difference (SPD proxy): 0
# Ratio SPD: 0.00
# Instance 2806: SPD (index difference) = 0.0
# Predicted Target Index: 6
# Gold Target Index: 7
# Index Difference (SPD proxy): 1
# Ratio SPD: 0.14
# Instance 3083: SPD (index difference) = 0.14285714285714285
# Predicted Target Index: 8
# Gold Target Index: 7
# Index Difference (SPD proxy): 1
# Ratio SPD: 0.11
# Instance 3590: SPD (index difference) = 0.1111111111111111
# Predicted Target Index: 6
# Gold Target Index: 5
# Index Difference (SPD proxy): 1
# Ratio SPD: 0.14
# Instance 1959: SPD (index difference) = 0.14285714285714285
# Predicted Target Index: 5
# Gold Target Index: 8
# Index Difference (SPD proxy): 3
# Ratio SPD: 0.50
# Instance 1300: SPD (index difference) = 0.5
# Predicted Target Index: 7
# Gold Target Index: 6
# Index Difference (SPD proxy): 1
# Ratio SPD: 0.12
# Instance 5428: SPD (index difference) = 0.125
# Predicted Target Index: 6
# Gold Target Index: 8
# Index Difference (SPD proxy): 2
# Ratio SPD: 0.29
# Instance 7349: SPD (index difference) = 0.2857142857142857
# Predicted Target Index: 7
# Gold Target Index: 6
# Index Difference (SPD proxy): 1
# Ratio SPD: 0.12
# Instance 4365: SPD (index difference) = 0.125
# Predicted Target Index: 6
# Gold Target Index: 11
# Index Difference (SPD proxy): 5
# Ratio SPD: 0.71
# Instance 5477: SPD (index difference) = 0.7142857142857143
# Predicted Target Index: 5
# Gold Target Index: 5
# Index Difference (SPD proxy): 0
# Ratio SPD: 0.00
# Instance 7595: SPD (index difference) = 0.0
# Predicted Target Index: 4
# Gold Target Index: 6
# Index Difference (SPD proxy): 2
# Ratio SPD: 0.40
# Instance 3638: SPD (index difference) = 0.4
# Predicted Target Index: 6
# Gold Target Index: 6
# Index Difference (SPD proxy): 0
# Ratio SPD: 0.00
# Instance 732: SPD (index difference) = 0.0
# Predicted Target Index: 7
# Gold Target Index: 5
# Index Difference (SPD proxy): 2
# Ratio SPD: 0.25
# Instance 2795: SPD (index difference) = 0.25
# Predicted Target Index: 6
# Gold Target Index: 6
# Index Difference (SPD proxy): 0
# Ratio SPD: 0.00
# Instance 7365: SPD (index difference) = 0.0
# Predicted Target Index: 8
# Gold Target Index: 8
# Index Difference (SPD proxy): 0
# Ratio SPD: 0.00
# Instance 3496: SPD (index difference) = 0.0
# Predicted Target Index: 7
# Gold Target Index: 10
# Index Difference (SPD proxy): 3
# Ratio SPD: 0.38
# Instance 4479: SPD (index difference) = 0.375
# Predicted Target Index: 7
# Gold Target Index: 9
# Index Difference (SPD proxy): 2
# Ratio SPD: 0.25
# Instance 617: SPD (index difference) = 0.25
# Predicted Target Index: 5
# Gold Target Index: 5
# Index Difference (SPD proxy): 0
# Ratio SPD: 0.00
# Instance 1702: SPD (index difference) = 0.0
# Predicted Target Index: 8
# Gold Target Index: 7
# Index Difference (SPD proxy): 1
# Ratio SPD: 0.11
# Instance 5846: SPD (index difference) = 0.1111111111111111
# Predicted Target Index: 8
# Gold Target Index: 13
# Index Difference (SPD proxy): 5
# Ratio SPD: 0.56
# Instance 4946: SPD (index difference) = 0.5555555555555556
# Predicted Target Index: 6
# Gold Target Index: 4
# Index Difference (SPD proxy): 2
# Ratio SPD: 0.29
# Instance 3557: SPD (index difference) = 0.2857142857142857
# Predicted Target Index: 6
# Gold Target Index: 8
# Index Difference (SPD proxy): 2
# Ratio SPD: 0.29
# Instance 4201: SPD (index difference) = 0.2857142857142857
# Predicted Target Index: 5
# Gold Target Index: 6
# Index Difference (SPD proxy): 1
# Ratio SPD: 0.17
# Instance 5090: SPD (index difference) = 0.16666666666666666
# Predicted Target Index: 9
# Gold Target Index: 9
# Index Difference (SPD proxy): 0
# Ratio SPD: 0.00
# Instance 5934: SPD (index difference) = 0.0
# Predicted Target Index: 8
# Gold Target Index: 8
# Index Difference (SPD proxy): 0
# Ratio SPD: 0.00
# Instance 6383: SPD (index difference) = 0.0
# Predicted Target Index: 9
# Gold Target Index: 7
# Index Difference (SPD proxy): 2
# Ratio SPD: 0.20
# Instance 6805: SPD (index difference) = 0.2
# Predicted Target Index: 7
# Gold Target Index: 10
# Index Difference (SPD proxy): 3
# Ratio SPD: 0.38
# Instance 2361: SPD (index difference) = 0.375
# Predicted Target Index: 7
# Gold Target Index: 7
# Index Difference (SPD proxy): 0
# Ratio SPD: 0.00
# Instance 4002: SPD (index difference) = 0.0
# Predicted Target Index: 10
# Gold Target Index: 11
# Index Difference (SPD proxy): 1
# Ratio SPD: 0.09
# Instance 7371: SPD (index difference) = 0.09090909090909091
# Predicted Target Index: 6
# Gold Target Index: 8
# Index Difference (SPD proxy): 2
# Ratio SPD: 0.29
# Instance 4989: SPD (index difference) = 0.2857142857142857
# Predicted Target Index: 5
# Gold Target Index: 9
# Index Difference (SPD proxy): 4
# Ratio SPD: 0.67
# Instance 2343: SPD (index difference) = 0.6666666666666666
# Predicted Target Index: 7
# Gold Target Index: 7
# Index Difference (SPD proxy): 0
# Ratio SPD: 0.00
# Instance 6111: SPD (index difference) = 0.0
# Predicted Target Index: 7
# Gold Target Index: 7
# Index Difference (SPD proxy): 0
# Ratio SPD: 0.00
# Instance 851: SPD (index difference) = 0.0
# Predicted Target Index: 7
# Gold Target Index: 8
# Index Difference (SPD proxy): 1
# Ratio SPD: 0.12
# Instance 1928: SPD (index difference) = 0.125
# Predicted Target Index: 7
# Gold Target Index: 6
# Index Difference (SPD proxy): 1
# Ratio SPD: 0.12
# Instance 7619: SPD (index difference) = 0.125
# Predicted Target Index: 7
# Gold Target Index: 7
# Index Difference (SPD proxy): 0
# Ratio SPD: 0.00
# Instance 3420: SPD (index difference) = 0.0
# Predicted Target Index: 6
# Gold Target Index: 7
# Index Difference (SPD proxy): 1
# Ratio SPD: 0.14
# Instance 5448: SPD (index difference) = 0.14285714285714285
# Predicted Target Index: 5
# Gold Target Index: 7
# Index Difference (SPD proxy): 2
# Ratio SPD: 0.33
# Instance 6094: SPD (index difference) = 0.3333333333333333
# Predicted Target Index: 6
# Gold Target Index: 5
# Index Difference (SPD proxy): 1
# Ratio SPD: 0.14
# Instance 435: SPD (index difference) = 0.14285714285714285
# Predicted Target Index: 8
# Gold Target Index: 4
# Index Difference (SPD proxy): 4
# Ratio SPD: 0.44
# Instance 7361: SPD (index difference) = 0.4444444444444444
# Predicted Target Index: 9
# Gold Target Index: 11
# Index Difference (SPD proxy): 2
# Ratio SPD: 0.20
# Instance 5868: SPD (index difference) = 0.2
# Predicted Target Index: 6
# Gold Target Index: 7
# Index Difference (SPD proxy): 1
# Ratio SPD: 0.14
# Instance 5853: SPD (index difference) = 0.14285714285714285
# Predicted Target Index: 4
# Gold Target Index: 6
# Index Difference (SPD proxy): 2
# Ratio SPD: 0.40
# Instance 309: SPD (index difference) = 0.4
# Predicted Target Index: 5
# Gold Target Index: 6
# Index Difference (SPD proxy): 1
# Ratio SPD: 0.17
# Instance 6598: SPD (index difference) = 0.16666666666666666
# Predicted Target Index: 7
# Gold Target Index: 8
# Index Difference (SPD proxy): 1
# Ratio SPD: 0.12
# Instance 3835: SPD (index difference) = 0.125
# Predicted Target Index: 7
# Gold Target Index: 7
# Index Difference (SPD proxy): 0
# Ratio SPD: 0.00
# Instance 607: SPD (index difference) = 0.0
# Predicted Target Index: 8
# Gold Target Index: 8
# Index Difference (SPD proxy): 0
# Ratio SPD: 0.00
# Instance 2257: SPD (index difference) = 0.0
# Predicted Target Index: 8
# Gold Target Index: 8
# Index Difference (SPD proxy): 0
# Ratio SPD: 0.00
# Instance 3666: SPD (index difference) = 0.0
# Predicted Target Index: 8
# Gold Target Index: 7
# Index Difference (SPD proxy): 1
# Ratio SPD: 0.11
# Instance 6682: SPD (index difference) = 0.1111111111111111
# Predicted Target Index: 7
# Gold Target Index: 7
# Index Difference (SPD proxy): 0
# Ratio SPD: 0.00
# Instance 7494: SPD (index difference) = 0.0
# Predicted Target Index: 8
# Gold Target Index: 8
# Index Difference (SPD proxy): 0
# Ratio SPD: 0.00
# Instance 3336: SPD (index difference) = 0.0
#
# Average SPD (index difference) over 200 instances: 0.17
